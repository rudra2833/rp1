# %% [markdown]
# **Name: Rudra P Patel**
#
#
#
# **Roll No.: 25MCE023**

# %% [markdown]
# **Practical-2: Basics of Tensor flow and Keras**

# %%
# learning the basics of tensorflow and keras

# %% [markdown]
# # Tensor Flow and Keras

# %% [markdown]
# BASICS OF PYTORCH

# %%
# Dropout randomly disables some neurons during training so that the model does not become too dependent on specific neurons.

# %% [markdown]
# an optimizer is an algorithm used to update the weights of a neural network to minimize the loss function, like:
#
# 1. Gradient Descent
# 2. stockastic Gradient Descent
# 3. adam optimizer

# %%
# Cross entropy loss measures the difference between the true probability distribution and the predicted probability distribution in classification problems.

# Softmax + Log + Loss - > Class index

# %%
# DataLoader helps in batching, shuffling, and parallel data loading.

# %% [markdown]
# model.eval() disables dropout and batch normalization behavior for inference.
#
#
# When Dropout is ENABLED (Training Mode → model.train())
#
#
# “Model learns like a team where some members randomly disappear, so everyone must contribute.”

# %% [markdown]
# Inference means using a trained model to make predictions on new/unseen data.

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# Sample data
x = torch.randn(100, 10)
y = torch.randint(0, 2, (100,))

# Model
class MyModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.fc1 = nn.Linear(10, 5)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(5, 2)

    def forward(self, x):
        x = self.fc1(x)
        x = self.relu(x)
        x = self.fc2(x)
        return x

model = MyModel()

# Loss & optimizer
loss_fn = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Training loop
for epoch in range(5):
    outputs = model(x)
    loss = loss_fn(outputs, y)

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    print(loss.item())

# %% [markdown]
# import tensorflow as tf
#
# x = tf.constant([1, 2, 3])

# %% [markdown]
# Keras is a high-level API in TensorFlow used to build models easily.

# %% [markdown]
# from tensorflow import keras
# from tensorflow.keras import layers
#
# model = keras.Sequential([
#     layers.Dense(5, activation='relu', input_shape=(10,)),
#     layers.Dense(2)
# ])
#
# <!-- inputs = keras.Input(shape=(10,))
# x = layers.Dense(5, activation='relu')(inputs)
# outputs = layers.Dense(2)(x)
#
# model = keras.Model(inputs, outputs) -->
#
# loss_fn = keras.losses.SparseCategoricalCrossentropy(from_logits=True)
# (from_logits=True → no softmax needed)
#
# optimizer = keras.optimizers.Adam(learning_rate=0.001)
#
# model.compile(
#     optimizer=optimizer,
#     loss=loss_fn,
#     metrics=['accuracy']
# )
#
# model.fit(x, y, epochs=5)
#
# model.evaluate(x, y)
#
# preds = model.predict(x)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# 1. Load / Create Data
x = tf.random.normal((100, 10))     # 100 samples, 10 features
y = tf.random.uniform((100,), maxval=2, dtype=tf.int32)  # 2 classes

# 2. Define Model
model = keras.Sequential([
    layers.Dense(64, activation='relu', input_shape=(10,)),
    layers.Dense(32, activation='relu'),
    layers.Dense(2)   # Output layer (no activation)
])

# 3. Compile Model
model.compile(
    optimizer='adam',
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy']
)

# 4. Train Model
model.fit(x, y, epochs=5, batch_size=32)

# 5. Evaluate Model
model.evaluate(x, y)

# 6. Predict (Inference)
predictions = model.predict(x)

# %%
now similar one in :
import torch
import torch.nn as nn

class MyModel(nn.Module):
    def __init__(self):
        super().__init__()

        self.fc1 = nn.Linear(10, 64)
        self.fc2 = nn.Linear(64, 32)
        self.fc3 = nn.Linear(32, 2)

        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.relu(self.fc1(x))
        x = self.relu(self.fc2(x))
        x = self.fc3(x)   # no activation (same as keras)

        return x
# Out:
#   File "/tmp/ipykernel_9544/3860089102.py", line 1
#     now similar one in :
#         ^
# SyntaxError: invalid syntax
